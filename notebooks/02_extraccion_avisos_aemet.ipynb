# %%
#importamos librerías necesarias
import pandas as pd
import requests
import os
from dotenv import load_dotenv
import tarfile
import gzip
import io
import xml.etree.ElementTree as ET
from datetime import datetime, timedelta
import time
import re

# %%
# cargamos API_KEY
load_dotenv()

API_KEY = os.getenv("AEMET_API_KEY")

if API_KEY is None:
    raise ValueError("No se ha encontrado la API Key. Revisa el archivo .env")
else:
    print("API Key cargada correctamente")
# Out:
# python-dotenv could not parse statement starting at line 2
# API Key cargada correctamente

# %%
# definimos fechas del proyecto 
fecha_inicio_total = datetime(2021, 1, 1)
fecha_fin_total = datetime(2026, 4, 30)

print("Fecha inicio:", fecha_inicio_total)
print("Fecha fin:", fecha_fin_total)
# Out:
# Fecha inicio: 2021-01-01 00:00:00
# Fecha fin: 2026-04-30 00:00:00

# %%
# Creamos rango de dos dias para la extracción de datos
rangos_fechas = []

fecha_actual = fecha_inicio_total

while fecha_actual <= fecha_fin_total:
    inicio = fecha_actual
    fin = min(fecha_actual + timedelta(days=1), fecha_fin_total)

    rangos_fechas.append((inicio, fin))

    fecha_actual = fin + timedelta(days=1)

print("Número de rangos creados:", len(rangos_fechas))

for inicio, fin in rangos_fechas[:10]:
    print(inicio.strftime("%Y-%m-%d"), "→", fin.strftime("%Y-%m-%d"))

print("...")

for inicio, fin in rangos_fechas[-10:]:
    print(inicio.strftime("%Y-%m-%d"), "→", fin.strftime("%Y-%m-%d"))
# Out:
# Número de rangos creados: 973
# 2021-01-01 → 2021-01-02
# 2021-01-03 → 2021-01-04
# 2021-01-05 → 2021-01-06
# 2021-01-07 → 2021-01-08
# 2021-01-09 → 2021-01-10
# 2021-01-11 → 2021-01-12
# 2021-01-13 → 2021-01-14
# 2021-01-15 → 2021-01-16
# 2021-01-17 → 2021-01-18
# 2021-01-19 → 2021-01-20
# ...
# 2026-04-11 → 2026-04-12
# 2026-04-13 → 2026-04-14
# 2026-04-15 → 2026-04-16
# 2026-04-17 → 2026-04-18
# 2026-04-19 → 2026-04-20
# 2026-04-21 → 2026-04-22
# 2026-04-23 → 2026-04-24
# 2026-04-25 → 2026-04-26
# 2026-04-27 → 2026-04-28
# 2026-04-29 → 2026-04-30

# %%
# funciones auxiliares para leer el XML de AEMET
def limpiar_tag(tag):
    if "}" in tag:
        return tag.split("}", 1)[1]
    return tag


def hijos(elemento, nombre):
    return [hijo for hijo in list(elemento) if limpiar_tag(hijo.tag) == nombre]


def texto(elemento, nombre):
    for hijo in list(elemento):
        if limpiar_tag(hijo.tag) == nombre:
            return hijo.text if hijo.text is not None else ""
    return ""

# %%
#funciones para descargar un rango de 2 dias 
def descargar_rango_aemet(fecha_inicio, fecha_fin, api_key, pausa=10, max_intentos=5):
    fecha_ini = fecha_inicio.strftime("%Y-%m-%dT00:00:00UTC")
    fecha_fin_str = fecha_fin.strftime("%Y-%m-%dT23:59:59UTC")

    url = (
        "https://opendata.aemet.es/opendata/api/avisos_cap/archivo/"
        f"fechaini/{fecha_ini}/fechafin/{fecha_fin_str}"
    )

    params = {
        "api_key": API_KEY
    }

    for intento in range(1, max_intentos + 1):
        print(f"Intento {intento}/{max_intentos}: {fecha_ini} → {fecha_fin_str}")

        # Primera llamada: pedir a AEMET la URL temporal
        response = requests.get(url, params=params, timeout=90)

        if response.status_code == 429:
            print("Demasiadas peticiones. Esperando 90 segundos...")
            time.sleep(90)
            continue

        if response.status_code != 200:
            print("Error en primera petición:", response.status_code)
            print(response.text[:500])
            time.sleep(pausa)
            continue

        try:
            respuesta_json = response.json()
        except Exception:
            print("La respuesta no es JSON")
            print(response.text[:500])
            time.sleep(pausa)
            continue

        url_datos = respuesta_json.get("datos")

        if not url_datos:
            print("No se encontró URL de datos")
            print(respuesta_json)
            time.sleep(pausa)
            continue

        time.sleep(pausa)

        # Segunda llamada: descargar el archivo real
        datos_response = requests.get(url_datos)

        if datos_response.status_code == 429:
            print("Demasiadas peticiones en descarga. Esperando 90 segundos...")
            time.sleep(90)
            continue

        if datos_response.status_code == 500:
            print("Error 500 en AEMET. Esperando y reintentando...")
            time.sleep(60)
            continue

        if datos_response.status_code != 200:
            print("Error descargando archivo real:", datos_response.status_code)
            print(datos_response.text[:500])
            time.sleep(pausa)
            continue

        contenido = datos_response.content

        # Comprobación mínima: parece TAR si empieza con nombre de archivo Z_CAP...
        if not contenido.startswith(b"Z_CAP"):
            print("El contenido descargado no parece el archivo esperado.")
            print(contenido[:300])
            time.sleep(pausa)
            continue

        print("Descarga correcta")
        return contenido

    print("No se pudo descargar este rango después de varios intentos.")
    return None

# %%
# Función para convertir TAR + GZ + XML en tabla
def convertir_contenido_a_dataframe(contenido):
    filas = []

    try:
        archivo_tar = tarfile.open(fileobj=io.BytesIO(contenido), mode="r:")
    except tarfile.TarError:
        print("No se pudo abrir como TAR")
        return pd.DataFrame()

    for miembro in archivo_tar.getmembers():

        if not miembro.name.endswith(".gz"):
            continue

        archivo_extraido = archivo_tar.extractfile(miembro)

        if archivo_extraido is None:
            continue

        contenido_gz = archivo_extraido.read()

        try:
            contenido_xml = gzip.decompress(contenido_gz)
        except gzip.BadGzipFile:
            continue

        texto_xml = contenido_xml.decode("utf-8", errors="ignore")

        bloques_xml = re.findall(
            r"<\?xml.*?</alert>",
            texto_xml,
            flags=re.DOTALL
        )

        for bloque in bloques_xml:

            try:
                root = ET.fromstring(bloque)
            except ET.ParseError:
                continue

            if limpiar_tag(root.tag) == "alert":
                alertas = [root]
            else:
                alertas = [
                    elem for elem in root.iter()
                    if limpiar_tag(elem.tag) == "alert"
                ]

            for alert in alertas:

                identifier = texto(alert, "identifier")
                sender = texto(alert, "sender")
                sent = texto(alert, "sent")
                status = texto(alert, "status")
                msg_type = texto(alert, "msgType")
                scope = texto(alert, "scope")

                for info in hijos(alert, "info"):

                    language = texto(info, "language")
                    category = texto(info, "category")
                    event = texto(info, "event")
                    urgency = texto(info, "urgency")
                    severity = texto(info, "severity")
                    certainty = texto(info, "certainty")
                    effective = texto(info, "effective")
                    onset = texto(info, "onset")
                    expires = texto(info, "expires")
                    headline = texto(info, "headline")
                    description = texto(info, "description")

                    areas = hijos(info, "area")

                    for area in areas:

                        area_desc = texto(area, "areaDesc")
                        polygon = texto(area, "polygon")
                        circle = texto(area, "circle")

                        geocode_valores = []

                        for geocode in hijos(area, "geocode"):
                            value_name = texto(geocode, "valueName")
                            value = texto(geocode, "value")

                            if value_name or value:
                                geocode_valores.append(f"{value_name}: {value}")

                        geocode_texto = " | ".join(geocode_valores)

                        filas.append({
                            "identifier": identifier,
                            "sender": sender,
                            "sent": sent,
                            "status": status,
                            "msg_type": msg_type,
                            "scope": scope,
                            "language": language,
                            "category": category,
                            "event": event,
                            "urgency": urgency,
                            "severity": severity,
                            "certainty": certainty,
                            "effective": effective,
                            "onset": onset,
                            "expires": expires,
                            "headline": headline,
                            "description": description,
                            "area_desc": area_desc,
                            "polygon": polygon,
                            "circle": circle,
                            "geocode": geocode_texto,
                            "archivo_origen": miembro.name
                        })

    return pd.DataFrame(filas)

# %%
# funciones para limpiar y crear nuevas columnas 
def limpiar_dataframe(df):
    if df.empty:
        return df

    df_limpio = df.drop_duplicates(
        subset=[
            "identifier",
            "sent",
            "onset",
            "expires",
            "event",
            "severity",
            "area_desc",
            "headline"
        ]
    ).copy()

    # Convertimos fechas usando utc=True para evitar errores con zonas horarias mixtas
    df_limpio["onset"] = pd.to_datetime(df_limpio["onset"], errors="coerce", utc=True)
    df_limpio["expires"] = pd.to_datetime(df_limpio["expires"], errors="coerce", utc=True)
    df_limpio["sent"] = pd.to_datetime(df_limpio["sent"], errors="coerce", utc=True)

    # Creamos año y mes
    df_limpio["año"] = df_limpio["onset"].dt.year
    df_limpio["mes_num"] = df_limpio["onset"].dt.month

    nombres_meses = {
        1: "Enero",
        2: "Febrero",
        3: "Marzo",
        4: "Abril",
        5: "Mayo",
        6: "Junio",
        7: "Julio",
        8: "Agosto",
        9: "Septiembre",
        10: "Octubre",
        11: "Noviembre",
        12: "Diciembre"
    }

    df_limpio["mes"] = df_limpio["mes_num"].map(nombres_meses)

    df_limpio["estacion"] = df_limpio["mes_num"].map({
        12: "Invierno",
        1: "Invierno",
        2: "Invierno",
        3: "Primavera",
        4: "Primavera",
        5: "Primavera",
        6: "Verano",
        7: "Verano",
        8: "Verano",
        9: "Otoño",
        10: "Otoño",
        11: "Otoño"
    })

    df_limpio["duracion_horas"] = (
        df_limpio["expires"] - df_limpio["onset"]
    ).dt.total_seconds() / 3600

    df_limpio["riesgo_numerico"] = df_limpio["severity"].map({
        "Minor": 0,
        "Moderate": 1,
        "Severe": 2,
        "Extreme": 3
    }).fillna(0)

    return df_limpio

# %%
# probamos con un solo rango antes que todo 
contenido_prueba = descargar_rango_aemet(
    datetime(2021, 1, 7),
    datetime(2021, 1, 8),
    API_KEY,
    pausa=12
)

df_prueba = convertir_contenido_a_dataframe(contenido_prueba)

df_prueba_limpio = limpiar_dataframe(df_prueba)

print("Filas prueba:", len(df_prueba_limpio))

df_prueba_limpio.head()
# Out:
# Intento 1/5: 2021-01-07T00:00:00UTC → 2021-01-08T23:59:59UTC
# Descarga correcta
# Filas prueba: 12604
#                                           identifier               sender  \
# 0  2.49.0.0.724.0.ES.20210107043640.750102BTTI070...  http://www.aemet.es
# 1  2.49.0.0.724.0.ES.20210107043640.750102BTTI070...  http://www.aemet.es
# 2  2.49.0.0.724.0.ES.20210106225001.624401NENV092...  http://www.aemet.es
# 3  2.49.0.0.724.0.ES.20210106225001.624401NENV092...  http://www.aemet.es
# 4  2.49.0.0.724.0.ES.20210106225001.624402NENV092...  http://www.aemet.es
#
#                        sent  status msg_type   scope language category  \
# 0 2021-01-07 04:36:40+00:00  Actual    Alert  Public    es-ES      Met
# 1 2021-01-07 04:36:40+00:00  Actual    Alert  Public    en-GB      Met
# 2 2021-01-06 22:50:01+00:00  Actual    Alert  Public    es-ES      Met
# 3 2021-01-06 22:50:01+00:00  Actual    Alert  Public    en-GB      Met
# 4 2021-01-06 22:50:01+00:00  Actual    Alert  Public    es-ES      Met
#
#                                              event    urgency  ...  \
# 0  Aviso de temperaturas mínimas de nivel amarillo  Immediate  ...
# 1                 Moderate low-temperature warning  Immediate  ...
# 2                Aviso de nevadas de nivel naranja     Future  ...
# 3                              Severe snow warning     Future  ...
# 4                Aviso de nevadas de nivel naranja     Future  ...
#
#                                              polygon circle  \
# 0  42.94,-2.98 42.94,-2.93 42.91,-2.86 42.92,-2.7...
# 1  42.94,-2.98 42.94,-2.93 42.91,-2.86 42.92,-2.7...
# 2  40.94,-1.62 40.94,-1.56 40.96,-1.5 40.96,-1.47...
# 3  40.94,-1.62 40.94,-1.56 40.96,-1.5 40.96,-1.47...
# 4  39.97,-1.14 40.01,-1.16 40.04,-1.08 40.06,-1.0...
#
#                           geocode                       archivo_origen   año  \
# 0  AEMET-Meteoalerta zona: 750102  Z_CAP_C_LEMM_20210107043640_AFAE.gz  2021
# 1  AEMET-Meteoalerta zona: 750102  Z_CAP_C_LEMM_20210107043640_AFAE.gz  2021
# 2  AEMET-Meteoalerta zona: 624401  Z_CAP_C_LEMM_20210107043640_AFAE.gz  2021
# 3  AEMET-Meteoalerta zona: 624401  Z_CAP_C_LEMM_20210107043640_AFAE.gz  2021
# 4  AEMET-Meteoalerta zona: 624402  Z_CAP_C_LEMM_20210107043640_AFAE.gz  2021
#
#   mes_num    mes  estacion duracion_horas riesgo_numerico
# 0       1  Enero  Invierno       3.999722               1
# 1       1  Enero  Invierno       3.999722               1
# 2       1  Enero  Invierno      23.999722               2
# 3       1  Enero  Invierno      23.999722               2
# 4       1  Enero  Invierno      23.999722               2
#
# [5 rows x 28 columns]

# %%
# Crear carpeta por meses 
import os

carpeta_salida = "avisos_aemet_por_mes"

os.makedirs(carpeta_salida, exist_ok=True)

print("Carpeta lista:", carpeta_salida)
# Out:
# Carpeta lista: avisos_aemet_por_mes

# %%
# creamos la lista de meses desde enero de 2021 hasta abril de 2026
meses_a_procesar = []

for anio in range(2021, 2027):
    for mes in range(1, 13):

        if anio == 2026 and mes > 4:
            continue

        meses_a_procesar.append((anio, mes))

print("Número de meses:", len(meses_a_procesar))
print(meses_a_procesar[:5])
print(meses_a_procesar[-5:])
# Out:
# Número de meses: 64
# [(2021, 1), (2021, 2), (2021, 3), (2021, 4), (2021, 5)]
# [(2025, 12), (2026, 1), (2026, 2), (2026, 3), (2026, 4)]

# %%
meses_a_procesar = []

for anio in range(2023, 2027):
    for mes in range(1, 13):

        if anio == 2023 and mes < 6:
            continue

        if anio == 2026 and mes > 4:
            continue

        meses_a_procesar.append((anio, mes))

print("Meses pendientes:", len(meses_a_procesar))
print(meses_a_procesar[:5])
print(meses_a_procesar[-5:])
# Out:
# Meses pendientes: 35
# [(2023, 6), (2023, 7), (2023, 8), (2023, 9), (2023, 10)]
# [(2025, 12), (2026, 1), (2026, 2), (2026, 3), (2026, 4)]

# %%
# descargar y guardar un CSV por cada mes
archivos_generados = []

for anio, mes in meses_a_procesar:

    print("=" * 80)
    print(f"PROCESANDO {anio}-{mes:02d}")
    print("=" * 80)

    # Primer y último día del mes
    fecha_inicio_mes = datetime(anio, mes, 1)

    if mes == 12:
        fecha_inicio_siguiente_mes = datetime(anio + 1, 1, 1)
    else:
        fecha_inicio_siguiente_mes = datetime(anio, mes + 1, 1)

    fecha_fin_mes = fecha_inicio_siguiente_mes - timedelta(days=1)

    # Dividir el mes en bloques de máximo 2 días
    rangos_mes = []
    fecha_actual = fecha_inicio_mes

    while fecha_actual <= fecha_fin_mes:
        inicio = fecha_actual
        fin = min(fecha_actual + timedelta(days=1), fecha_fin_mes)

        rangos_mes.append((inicio, fin))

        fecha_actual = fin + timedelta(days=1)

    print("Rangos de 2 días en este mes:", len(rangos_mes))

    dfs_mes = []

    for inicio, fin in rangos_mes:

        contenido = descargar_rango_aemet(
            inicio,
            fin,
            API_KEY,
            pausa=8,
            max_intentos=5
        )

        if contenido is None:
            print("No se pudo descargar este rango. Se pasa al siguiente.")
            continue

        df_rango = convertir_contenido_a_dataframe(contenido)

        if df_rango.empty:
            print("No se encontraron datos en este rango.")
            continue

        df_rango_limpio = limpiar_dataframe(df_rango)

        if df_rango_limpio.empty:
            print("El rango quedó vacío después de limpiar.")
            continue

        dfs_mes.append(df_rango_limpio)

        print("Filas limpias del rango:", len(df_rango_limpio))

    if len(dfs_mes) == 0:
        print(f"No se obtuvieron datos para {anio}-{mes:02d}")
        continue

    # Unir todos los rangos del mes
    df_mes = pd.concat(dfs_mes, ignore_index=True)

    # Quitar duplicados dentro del mes
    df_mes_limpio = df_mes.drop_duplicates(
        subset=[
            "identifier",
            "sent",
            "onset",
            "expires",
            "event",
            "severity",
            "area_desc",
            "headline"
        ]
    ).copy()

    print("Filas del mes antes de limpieza final:", len(df_mes))
    print("Filas del mes después de limpieza final:", len(df_mes_limpio))

    nombre_archivo = f"{carpeta_salida}/avisos_aemet_{anio}_{mes:02d}.csv"

    df_mes_limpio.to_csv(
        nombre_archivo,
        index=False,
        encoding="utf-8-sig"
    )

    archivos_generados.append(nombre_archivo)

    print("Archivo mensual guardado:", nombre_archivo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # descargar y guardar un CSV por cada mes
#       2 archivos_generados = []
# ----> 4 for anio, mes in meses_a_procesar:
#       6     print("=" * 80)
#       7     print(f"PROCESANDO {anio}-{mes:02d}")
#
# NameError: name 'meses_a_procesar' is not defined

# %%
# comprobar archivos mensuales generados
print("Número de archivos mensuales generados:", len(archivos_generados))

archivos_generados[:10]
# Out:
# Número de archivos mensuales generados: 0
# []

# %%
import pandas as pd
import glob
import os

# %%
archivos = sorted(glob.glob("avisos_aemet_por_mes/*.csv"))

print("Archivos encontrados:", len(archivos))
print("Primeros archivos:")
print(archivos[:5])
print("Últimos archivos:")
print(archivos[-5:])
# Out:
# Archivos encontrados: 64
# Primeros archivos:
# ['avisos_aemet_por_mes\\avisos_aemet_2021_01.csv', 'avisos_aemet_por_mes\\avisos_aemet_2021_02.csv', 'avisos_aemet_por_mes\\avisos_aemet_2021_03.csv', 'avisos_aemet_por_mes\\avisos_aemet_2021_04.csv', 'avisos_aemet_por_mes\\avisos_aemet_2021_05.csv']
# Últimos archivos:
# ['avisos_aemet_por_mes\\avisos_aemet_2025_12.csv', 'avisos_aemet_por_mes\\avisos_aemet_2026_01.csv', 'avisos_aemet_por_mes\\avisos_aemet_2026_02.csv', 'avisos_aemet_por_mes\\avisos_aemet_2026_03.csv', 'avisos_aemet_por_mes\\avisos_aemet_2026_04.csv']

# %%
archivos = sorted(
    glob.glob(
        r"C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\*.csv"
    )
)

print("Archivos encontrados:", len(archivos))
print(archivos[:5])
print(archivos[-5:])
# Out:
# Archivos encontrados: 64
# ['C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2021_01.csv', 'C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2021_02.csv', 'C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2021_03.csv', 'C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2021_04.csv', 'C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2021_05.csv']
# ['C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2025_12.csv', 'C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2026_01.csv', 'C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2026_02.csv', 'C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2026_03.csv', 'C:\\Users\\Marta\\Desktop\\Adalab\\proyectos\\proyecto-modulo-4\\proyecto-da-promo-63-modulo-4-team2-proyectofinal\\avisos_aemet_por_mes\\avisos_aemet_2026_04.csv']

# %%
columnas_finales = [
    "onset",
    "expires",
    "año",
    "mes",
    "mes_num",
    "estacion",
    "event",
    "severity",
    "riesgo_numerico",
    "duracion_horas",
    "area_desc",
]

columnas_duplicados = ["onset", "expires", "event", "severity", "area_desc"]

# %%
archivo_salida = "avisos_aemet_2021_2026_moderate_severe_extreme.csv"

if os.path.exists(archivo_salida):
    os.remove(archivo_salida)

primera_vez = True
total_filas_guardadas = 0

niveles_seleccionados = ["Moderate", "Severe", "Extreme"]

for archivo in archivos:
    print("=" * 80)
    print("Procesando:", archivo)
    print("=" * 80)

    try:
        lector = pd.read_csv(
            archivo,
            chunksize=50000,
            encoding="utf-8-sig",
            low_memory=False,
            on_bad_lines="skip",
        )

        for i, chunk in enumerate(lector):
            print(f"  Bloque {i + 1}")

            if "severity" not in chunk.columns:
                print("  Este bloque no tiene columna severity")
                continue

            # Filtrar solo Moderate, Severe y Extreme
            chunk = chunk[chunk["severity"].isin(niveles_seleccionados)]

            if chunk.empty:
                print("  No hay filas Moderate, Severe o Extreme en este bloque")
                continue

            columnas_disponibles = [
                col for col in columnas_finales if col in chunk.columns
            ]

            chunk = chunk[columnas_disponibles]

            columnas_dup_disponibles = [
                col for col in columnas_duplicados if col in chunk.columns
            ]

            if len(columnas_dup_disponibles) > 0:
                chunk = chunk.drop_duplicates(subset=columnas_dup_disponibles)

            chunk.to_csv(
                archivo_salida,
                mode="w" if primera_vez else "a",
                header=primera_vez,
                index=False,
                encoding="utf-8-sig",
            )

            primera_vez = False
            total_filas_guardadas += len(chunk)

            print("  Filas añadidas:", len(chunk))
            print("  Total acumulado:", total_filas_guardadas)

    except Exception as e:
        print("ERROR con archivo:")
        print(archivo)
        print(e)
        continue

print("Proceso terminado")
print("Archivo creado:", archivo_salida)
print("Filas aproximadas guardadas:", total_filas_guardadas)
# Out:
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_01.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 6272
#   Total acumulado: 6272
#   Bloque 2
#   Filas añadidas: 4440
#   Total acumulado: 10712
#   Bloque 3
#   Filas añadidas: 1722
#   Total acumulado: 12434
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_02.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2824
#   Total acumulado: 15258
#   Bloque 2
#   Filas añadidas: 1854
#   Total acumulado: 17112
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_03.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 734
#   Total acumulado: 17846
#   Bloque 2
#   Filas añadidas: 1236
#   Total acumulado: 19082
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_04.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 850
#   Total acumulado: 19932
#   Bloque 2
#   Filas añadidas: 1060
#   Total acumulado: 20992
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_05.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 690
#   Total acumulado: 21682
#   Bloque 2
#   Filas añadidas: 1436
#   Total acumulado: 23118
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_06.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2812
#   Total acumulado: 25930
#   Bloque 2
#   Filas añadidas: 2356
#   Total acumulado: 28286
#   Bloque 3
#   Filas añadidas: 50
#   Total acumulado: 28336
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_07.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1674
#   Total acumulado: 30010
#   Bloque 2
#   Filas añadidas: 1894
#   Total acumulado: 31904
#   Bloque 3
#   Filas añadidas: 350
#   Total acumulado: 32254
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_08.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2938
#   Total acumulado: 35192
#   Bloque 2
#   Filas añadidas: 2126
#   Total acumulado: 37318
#   Bloque 3
#   Filas añadidas: 1410
#   Total acumulado: 38728
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_09.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3070
#   Total acumulado: 41798
#   Bloque 2
#   Filas añadidas: 2352
#   Total acumulado: 44150
#   Bloque 3
#   Filas añadidas: 106
#   Total acumulado: 44256
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_10.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 992
#   Total acumulado: 45248
#   Bloque 2
#   Filas añadidas: 1190
#   Total acumulado: 46438
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_11.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1684
#   Total acumulado: 48122
#   Bloque 2
#   Filas añadidas: 3084
#   Total acumulado: 51206
#   Bloque 3
#   Filas añadidas: 240
#   Total acumulado: 51446
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_12.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3596
#   Total acumulado: 55042
#   Bloque 2
#   Filas añadidas: 1552
#   Total acumulado: 56594
#   Bloque 3
#   Filas añadidas: 96
#   Total acumulado: 56690
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_01.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2294
#   Total acumulado: 58984
#   Bloque 2
#   Filas añadidas: 2364
#   Total acumulado: 61348
#   Bloque 3
#   Filas añadidas: 304
#   Total acumulado: 61652
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_02.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 812
#   Total acumulado: 62464
#   Bloque 2
#   Filas añadidas: 1340
#   Total acumulado: 63804
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_03.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2370
#   Total acumulado: 66174
#   Bloque 2
#   Filas añadidas: 2692
#   Total acumulado: 68866
#   Bloque 3
#   Filas añadidas: 472
#   Total acumulado: 69338
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_04.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1646
#   Total acumulado: 70984
#   Bloque 2
#   Filas añadidas: 1382
#   Total acumulado: 72366
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_05.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 948
#   Total acumulado: 73314
#   Bloque 2
#   Filas añadidas: 894
#   Total acumulado: 74208
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_06.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2722
#   Total acumulado: 76930
#   Bloque 2
#   Filas añadidas: 1752
#   Total acumulado: 78682
#   Bloque 3
#   Filas añadidas: 22
#   Total acumulado: 78704
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_07.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3168
#   Total acumulado: 81872
#   Bloque 2
#   Filas añadidas: 3008
#   Total acumulado: 84880
#   Bloque 3
#   Filas añadidas: 1154
#   Total acumulado: 86034
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_08.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3370
#   Total acumulado: 89404
#   Bloque 2
#   Filas añadidas: 2438
#   Total acumulado: 91842
#   Bloque 3
#   Filas añadidas: 210
#   Total acumulado: 92052
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_09.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1438
#   Total acumulado: 93490
#   Bloque 2
#   Filas añadidas: 2482
#   Total acumulado: 95972
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_10.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1506
#   Total acumulado: 97478
#   Bloque 2
#   Filas añadidas: 1722
#   Total acumulado: 99200
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_11.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1470
#   Total acumulado: 100670
#   Bloque 2
#   Filas añadidas: 2638
#   Total acumulado: 103308
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_12.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2512
#   Total acumulado: 105820
#   Bloque 2
#   Filas añadidas: 1646
#   Total acumulado: 107466
#   Bloque 3
#   Filas añadidas: 250
#   Total acumulado: 107716
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_01.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2230
#   Total acumulado: 109946
#   Bloque 2
#   Filas añadidas: 4510
#   Total acumulado: 114456
#   Bloque 3
#   Filas añadidas: 494
#   Total acumulado: 114950
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_02.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2516
#   Total acumulado: 117466
#   Bloque 2
#   Filas añadidas: 2766
#   Total acumulado: 120232
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_03.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1520
#   Total acumulado: 121752
#   Bloque 2
#   Filas añadidas: 1018
#   Total acumulado: 122770
#   Bloque 3
#   Filas añadidas: 230
#   Total acumulado: 123000
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_04.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1206
#   Total acumulado: 124206
#   Bloque 2
#   Filas añadidas: 414
#   Total acumulado: 124620
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_05.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1318
#   Total acumulado: 125938
#   Bloque 2
#   Filas añadidas: 3842
#   Total acumulado: 129780
#   Bloque 3
#   Filas añadidas: 772
#   Total acumulado: 130552
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_06.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 5178
#   Total acumulado: 135730
#   Bloque 2
#   Filas añadidas: 3418
#   Total acumulado: 139148
#   Bloque 3
#   Filas añadidas: 394
#   Total acumulado: 139542
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_07.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2518
#   Total acumulado: 142060
#   Bloque 2
#   Filas añadidas: 1934
#   Total acumulado: 143994
#   Bloque 3
#   Filas añadidas: 330
#   Total acumulado: 144324
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_08.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2762
#   Total acumulado: 147086
#   Bloque 2
#   Filas añadidas: 3662
#   Total acumulado: 150748
#   Bloque 3
#   Filas añadidas: 984
#   Total acumulado: 151732
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_09.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 4560
#   Total acumulado: 156292
#   Bloque 2
#   Filas añadidas: 2234
#   Total acumulado: 158526
#   Bloque 3
#   Filas añadidas: 68
#   Total acumulado: 158594
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_10.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 804
#   Total acumulado: 159398
#   Bloque 2
#   Filas añadidas: 4582
#   Total acumulado: 163980
#   Bloque 3
#   Filas añadidas: 1256
#   Total acumulado: 165236
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_11.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 4040
#   Total acumulado: 169276
#   Bloque 2
#   Filas añadidas: 956
#   Total acumulado: 170232
#   Bloque 3
#   Filas añadidas: 300
#   Total acumulado: 170532
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_12.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1418
#   Total acumulado: 171950
#   Bloque 2
#   Filas añadidas: 1156
#   Total acumulado: 173106
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_01.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1860
#   Total acumulado: 174966
#   Bloque 2
#   Filas añadidas: 2164
#   Total acumulado: 177130
#   Bloque 3
#   Filas añadidas: 26
#   Total acumulado: 177156
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_02.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1690
#   Total acumulado: 178846
#   Bloque 2
#   Filas añadidas: 3486
#   Total acumulado: 182332
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_03.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2562
#   Total acumulado: 184894
#   Bloque 2
#   Filas añadidas: 3034
#   Total acumulado: 187928
#   Bloque 3
#   Filas añadidas: 360
#   Total acumulado: 188288
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_04.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1006
#   Total acumulado: 189294
#   Bloque 2
#   Filas añadidas: 580
#   Total acumulado: 189874
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_05.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 768
#   Total acumulado: 190642
#   Bloque 2
#   Filas añadidas: 660
#   Total acumulado: 191302
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_06.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2122
#   Total acumulado: 193424
#   Bloque 2
#   Filas añadidas: 2414
#   Total acumulado: 195838
#   Bloque 3
#   Filas añadidas: 24
#   Total acumulado: 195862
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_07.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1488
#   Total acumulado: 197350
#   Bloque 2
#   Filas añadidas: 3066
#   Total acumulado: 200416
#   Bloque 3
#   Filas añadidas: 622
#   Total acumulado: 201038
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_08.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2972
#   Total acumulado: 204010
#   Bloque 2
#   Filas añadidas: 2064
#   Total acumulado: 206074
#   Bloque 3
#   Filas añadidas: 1308
#   Total acumulado: 207382
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_09.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2276
#   Total acumulado: 209658
#   Bloque 2
#   Filas añadidas: 2552
#   Total acumulado: 212210
#   Bloque 3
#   Filas añadidas: 10
#   Total acumulado: 212220
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_10.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3006
#   Total acumulado: 215226
#   Bloque 2
#   Filas añadidas: 3406
#   Total acumulado: 218632
#   Bloque 3
#   Filas añadidas: 718
#   Total acumulado: 219350
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_11.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2500
#   Total acumulado: 221850
#   Bloque 2
#   Filas añadidas: 2258
#   Total acumulado: 224108
#   Bloque 3
#   Filas añadidas: 78
#   Total acumulado: 224186
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_12.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2392
#   Total acumulado: 226578
#   Bloque 2
#   Filas añadidas: 2316
#   Total acumulado: 228894
#   Bloque 3
#   Filas añadidas: 350
#   Total acumulado: 229244
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_01.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2314
#   Total acumulado: 231558
#   Bloque 2
#   Filas añadidas: 4168
#   Total acumulado: 235726
#   Bloque 3
#   Filas añadidas: 286
#   Total acumulado: 236012
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_02.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 552
#   Total acumulado: 236564
#   Bloque 2
#   Filas añadidas: 892
#   Total acumulado: 237456
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_03.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3832
#   Total acumulado: 241288
#   Bloque 2
#   Filas añadidas: 2788
#   Total acumulado: 244076
#   Bloque 3
#   Filas añadidas: 62
#   Total acumulado: 244138
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_04.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1914
#   Total acumulado: 246052
#   Bloque 2
#   Filas añadidas: 1098
#   Total acumulado: 247150
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_05.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3654
#   Total acumulado: 250804
#   Bloque 2
#   Filas añadidas: 1088
#   Total acumulado: 251892
#   Bloque 3
#   Filas añadidas: 330
#   Total acumulado: 252222
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_06.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2940
#   Total acumulado: 255162
#   Bloque 2
#   Filas añadidas: 5146
#   Total acumulado: 260308
#   Bloque 3
#   Filas añadidas: 1194
#   Total acumulado: 261502
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_07.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 5074
#   Total acumulado: 266576
#   Bloque 2
#   Filas añadidas: 2414
#   Total acumulado: 268990
#   Bloque 3
#   Filas añadidas: 382
#   Total acumulado: 269372
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_08.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 4400
#   Total acumulado: 273772
#   Bloque 2
#   Filas añadidas: 3192
#   Total acumulado: 276964
#   Bloque 3
#   Filas añadidas: 406
#   Total acumulado: 277370
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_09.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1790
#   Total acumulado: 279160
#   Bloque 2
#   Filas añadidas: 2420
#   Total acumulado: 281580
#   Bloque 3
#   No hay filas Moderate, Severe o Extreme en este bloque
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_10.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1936
#   Total acumulado: 283516
#   Bloque 2
#   Filas añadidas: 1876
#   Total acumulado: 285392
#   Bloque 3
#   Filas añadidas: 84
#   Total acumulado: 285476
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_11.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3370
#   Total acumulado: 288846
#   Bloque 2
#   Filas añadidas: 1598
#   Total acumulado: 290444
#   Bloque 3
#   Filas añadidas: 102
#   Total acumulado: 290546
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_12.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2590
#   Total acumulado: 293136
#   Bloque 2
#   Filas añadidas: 2054
#   Total acumulado: 295190
#   Bloque 3
#   Filas añadidas: 216
#   Total acumulado: 295406
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_01.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 3132
#   Total acumulado: 298538
#   Bloque 2
#   Filas añadidas: 6042
#   Total acumulado: 304580
#   Bloque 3
#   Filas añadidas: 1696
#   Total acumulado: 306276
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_02.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 6818
#   Total acumulado: 313094
#   Bloque 2
#   Filas añadidas: 2624
#   Total acumulado: 315718
#   Bloque 3
#   Filas añadidas: 68
#   Total acumulado: 315786
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_03.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 2520
#   Total acumulado: 318306
#   Bloque 2
#   Filas añadidas: 2680
#   Total acumulado: 320986
#   Bloque 3
#   Filas añadidas: 402
#   Total acumulado: 321388
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_04.csv
# ================================================================================
#   Bloque 1
#   Filas añadidas: 1868
#   Total acumulado: 323256
#   Bloque 2
#   Filas añadidas: 2538
#   Total acumulado: 325794
#   Bloque 3
#   Filas añadidas: 12
#   Total acumulado: 325806
# Proceso terminado
# Archivo creado: avisos_aemet_2021_2026_moderate_severe_extreme.csv
# Filas aproximadas guardadas: 325806

# %%
archivo = "avisos_aemet_2021_2026_moderate_severe_extreme.csv"

total_filas = 0
columnas = None
conteo_severity = {}

for chunk in pd.read_csv(
    archivo, chunksize=50000, encoding="utf-8-sig", low_memory=False
):
    total_filas += len(chunk)

    if columnas is None:
        columnas = chunk.columns.tolist()

    conteo = chunk["severity"].value_counts()

    for nivel, cantidad in conteo.items():
        conteo_severity[nivel] = conteo_severity.get(nivel, 0) + cantidad

print("Filas:", total_filas)
print("Columnas:", len(columnas))
print("Nombres de columnas:")
print(columnas)

print("Conteo severity:")
print(conteo_severity)
# Out:
# Filas: 325806
# Columnas: 11
# Nombres de columnas:
# ['onset', 'expires', 'año', 'mes', 'mes_num', 'estacion', 'event', 'severity', 'riesgo_numerico', 'duracion_horas', 'area_desc']
# Conteo severity:
# {'Moderate': 281140, 'Severe': 43018, 'Extreme': 1648}

# %%
import os

archivo = "avisos_aemet_2021_2026_moderate_severe_extreme.csv"

tamaño_bytes = os.path.getsize(archivo)
tamaño_mb = tamaño_bytes / (1024 * 1024)

print("Tamaño en bytes:", tamaño_bytes)
print("Tamaño en MB:", round(tamaño_mb, 2))
# Out:
# Tamaño en bytes: 51852748
# Tamaño en MB: 49.45

# %%
# definimos las columnas
columnas_utiles = [
    "identifier",
    "sent",
    "onset",
    "expires",
    "año",
    "mes",
    "estacion",
    "event",
    "severity",
    "riesgo_numerico",
    "duracion_horas",
    "area_desc",
    "geocode",
]

# %%
# columnas duplicadas
columnas_duplicados = [
    "identifier",
    "sent",
    "onset",
    "expires",
    "event",
    "severity",
    "area_desc",
]

# %%
archivo_salida = "avisos_aemet_2021_2026_super_ligero_tableau.csv"

if os.path.exists(archivo_salida):
    os.remove(archivo_salida)

primera_vez = True
total_filas_guardadas = 0

for archivo in archivos:
    print("=" * 80)
    print("Procesando:", archivo)
    print("=" * 80)

    try:
        lector = pd.read_csv(
            archivo,
            chunksize=50000,
            encoding="utf-8-sig",
            low_memory=False,
            on_bad_lines="skip",
        )

        for i, chunk in enumerate(lector):
            print(f"  Bloque {i + 1}")

            columnas_disponibles = [
                col for col in columnas_super_ligeras if col in chunk.columns
            ]

            chunk = chunk[columnas_disponibles]

            columnas_dup_disponibles = [
                col for col in columnas_duplicados if col in chunk.columns
            ]

            if len(columnas_dup_disponibles) > 0:
                chunk = chunk.drop_duplicates(subset=columnas_dup_disponibles)

            chunk.to_csv(
                archivo_salida,
                mode="w" if primera_vez else "a",
                header=primera_vez,
                index=False,
                encoding="utf-8-sig",
            )

            primera_vez = False
            total_filas_guardadas += len(chunk)

            print("  Filas añadidas:", len(chunk))
            print("  Total acumulado:", total_filas_guardadas)

    except Exception as e:
        print("ERROR con archivo:")
        print(archivo)
        print(e)
        continue

print("Proceso terminado")
print("Archivo creado:", archivo_salida)
print("Filas aproximadas guardadas:", total_filas_guardadas)
# Out:
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_01.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_01.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_02.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_02.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_03.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_03.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_04.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_04.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_05.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_05.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_06.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_06.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_07.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_07.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_08.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_08.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_09.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_09.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_10.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_10.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_11.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_11.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_12.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2021_12.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_01.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_01.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_02.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_02.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_03.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_03.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_04.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_04.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_05.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_05.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_06.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_06.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_07.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_07.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_08.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_08.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_09.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_09.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_10.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_10.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_11.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_11.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_12.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2022_12.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_01.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_01.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_02.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_02.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_03.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_03.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_04.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_04.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_05.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_05.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_06.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_06.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_07.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_07.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_08.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_08.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_09.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_09.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_10.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_10.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_11.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_11.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_12.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2023_12.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_01.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_01.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_02.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_02.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_03.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_03.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_04.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_04.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_05.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_05.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_06.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_06.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_07.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_07.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_08.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_08.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_09.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_09.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_10.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_10.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_11.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_11.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_12.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2024_12.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_01.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_01.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_02.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_02.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_03.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_03.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_04.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_04.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_05.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_05.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_06.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_06.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_07.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_07.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_08.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_08.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_09.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_09.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_10.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_10.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_11.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_11.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_12.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2025_12.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_01.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_01.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_02.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_02.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_03.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_03.csv
# name 'columnas_super_ligeras' is not defined
# ================================================================================
# Procesando: C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_04.csv
# ================================================================================
#   Bloque 1
# ERROR con archivo:
# C:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal\avisos_aemet_por_mes\avisos_aemet_2026_04.csv
# name 'columnas_super_ligeras' is not defined
# Proceso terminado
# Archivo creado: avisos_aemet_2021_2026_super_ligero_tableau.csv
# Filas aproximadas guardadas: 0

# %%
archivo = "avisos_aemet_2021_2026_super_ligero_tableau.csv"

total_filas = 0
columnas = None

for chunk in pd.read_csv(
    archivo, chunksize=50000, encoding="utf-8-sig", low_memory=False
):
    total_filas += len(chunk)

    if columnas is None:
        columnas = chunk.columns.tolist()

print("Filas:", total_filas)
print("Columnas:", len(columnas))
print("Nombres de columnas:")
print(columnas)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 6
#       3 total_filas = 0
#       4 columnas = None
# ----> 6 for chunk in pd.read_csv(
#       7     archivo, chunksize=50000, encoding="utf-8-sig", low_memory=False
#       8 ):
#       9     total_filas += len(chunk)
#      11     if columnas is None:
#
# File c:\Users\Marta\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Marta\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Marta\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Marta\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Marta\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'avisos_aemet_2021_2026_super_ligero_tableau.csv'

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Marta\Desktop\Adalab\proyectos\proyecto-modulo-4\proyecto-da-promo-63-modulo-4-team2-proyectofinal

# %%
import glob

csvs = glob.glob("*.csv")

print("CSV encontrados:", len(csvs))
csvs
# Out:
# CSV encontrados: 4
# ['datos_dana_emergencias.csv',
#  'datos_dana_unificados.csv',
#  'datos_filomena_emergencias.csv',
#  'datos_filomena_unificados.csv']

# %%
csvs_todos = glob.glob("**/*.csv", recursive=True)

print("CSV encontrados en subcarpetas:", len(csvs_todos))
csvs_todos[:50]
# Out:
# CSV encontrados en subcarpetas: 68
# ['datos_dana_emergencias.csv',
#  'datos_dana_unificados.csv',
#  'datos_filomena_emergencias.csv',
#  'datos_filomena_unificados.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_01.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_02.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_03.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_04.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_05.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_06.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_07.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_08.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_09.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_10.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_11.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2021_12.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_01.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_02.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_03.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_04.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_05.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_06.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_07.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_08.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_09.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_10.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_11.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2022_12.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_01.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_02.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_03.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_04.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_05.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_06.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_07.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_08.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_09.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_10.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_11.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2023_12.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_01.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_02.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_03.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_04.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_05.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_06.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_07.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_08.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_09.csv',
#  'avisos_aemet_por_mes\\avisos_aemet_2024_10.csv']

# %%
import zipfile

archivo_csv = "avisos_aemet_2021_2026_moderate_severe_extreme.csv"
archivo_zip = "avisos_aemet_2021_2026_moderate_severe_extreme.zip"

with zipfile.ZipFile(archivo_zip, "w", zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(archivo_csv)

print("ZIP creado:", archivo_zip)
# Out:
# ZIP creado: avisos_aemet_2021_2026_moderate_severe_extreme.zip
