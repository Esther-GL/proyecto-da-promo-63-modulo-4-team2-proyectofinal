# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# cargar csv
df_avisos_aemet = pd.read_csv("avisos_aemet_2021_2026_moderate_severe_extreme.csv", encoding="latin-1")

# %%
df_avisos_aemet.head()
# Out:
#                     ï»¿onset                    expires  aÃ±o    mes  mes_num  \
# 0  2021-01-01 06:00:00+00:00  2021-01-01 19:59:59+00:00  2021  Enero        1
# 1  2021-01-01 06:00:00+00:00  2021-01-01 19:59:59+00:00  2021  Enero        1
# 2  2021-01-01 06:00:00+00:00  2021-01-01 19:59:59+00:00  2021  Enero        1
# 3  2021-01-01 06:00:00+00:00  2021-01-01 19:59:59+00:00  2021  Enero        1
# 4  2021-01-01 06:00:00+00:00  2021-01-01 20:59:59+00:00  2021  Enero        1
#
#    estacion                               event  severity  riesgo_numerico  \
# 0  Invierno  Aviso de vientos de nivel amarillo  Moderate                1
# 1  Invierno               Moderate wind warning  Moderate                1
# 2  Invierno  Aviso de vientos de nivel amarillo  Moderate                1
# 3  Invierno               Moderate wind warning  Moderate                1
# 4  Invierno  Aviso de vientos de nivel amarillo  Moderate                1
#
# ...

# %%
df_avisos_aemet.columns
# Out:
# Index(['ï»¿onset', 'expires', 'aÃ±o', 'mes', 'mes_num', 'estacion', 'event',
#        'severity', 'riesgo_numerico', 'duracion_horas', 'area_desc'],
#       dtype='object')

# %%
df_avisos_aemet.shape
# Out:
# (325806, 11)

# %%
df_avisos_aemet.tail()
# Out:
#                          ï»¿onset                    expires  aÃ±o    mes  \
# 325801  2026-04-30 22:00:00+00:00  2026-05-01 06:59:59+00:00  2026  Abril
# 325802  2026-04-30 22:02:33+00:00  2026-04-30 22:02:34+00:00  2026  Abril
# 325803  2026-04-30 22:02:33+00:00  2026-04-30 22:02:34+00:00  2026  Abril
# 325804  2026-04-30 22:02:33+00:00  2026-04-30 22:02:34+00:00  2026  Abril
# 325805  2026-04-30 22:02:33+00:00  2026-04-30 22:02:34+00:00  2026  Abril
#
#         mes_num   estacion                                 event  severity  \
# 325801        4  Primavera         Moderate thunderstorm warning  Moderate
# 325802        4  Primavera    Aviso de lluvias de nivel amarillo  Moderate
# 325803        4  Primavera                 Moderate rain warning  Moderate
# 325804        4  Primavera  Aviso de tormentas de nivel amarillo  Moderate
# 325805        4  Primavera         Moderate thunderstorm warning  Moderate
#
#         riesgo_numerico  duracion_horas            area_desc
# ...

# %%
df_avisos_aemet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325806 entries, 0 to 325805
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ï»¿onset         325806 non-null  object
#  1   expires          325806 non-null  object
#  2   aÃ±o             325806 non-null  int64
#  3   mes              325806 non-null  object
#  4   mes_num          325806 non-null  int64
#  5   estacion         325806 non-null  object
#  6   event            325806 non-null  object
#  7   severity         325806 non-null  object
#  8   riesgo_numerico  325806 non-null  int64
#  9   duracion_horas   325806 non-null  float64
#  10  area_desc        325806 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 27.3+ MB

# %%
df_avisos_aemet["event"].value_counts()
# Out:
# event
# Moderate rain warning                  33943
# Aviso de lluvias de nivel amarillo     33943
# Aviso de costeros de nivel amarillo    26428
# Moderate coastalevent warning          26428
# Moderate thunderstorm warning          25049
#                                        ...
# Aviso de aludes de nivel naranja           5
# Severe galerna warning                     4
# Aviso de galernas de nivel naranja         4
# Extreme galerna warning                    1
# Aviso de galernas de nivel rojo            1
# Name: count, Length: 62, dtype: int64
